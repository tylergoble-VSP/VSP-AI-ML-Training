# %% [markdown]
# # Mid-Level Machine Learning Engineer - Technical Interview
#
# ## Welcome!
#
# This is a practical coding assessment designed to evaluate your problem-solving approach and ML fundamentals.
#
# **Guidelines:**
# - **Time limit:** 25 minutes
# - **Resources:** You may use Google/documentation (no AI coding assistants)
# - **Focus:** We want to see how you think, not perfect code. Partial solutions with good reasoning are valued.
# - **Questions:** Feel free to ask clarifying questions at any time
#
# **What we're evaluating:**
# 1. Problem-solving approach and reasoning
# 2. Python fundamentals (data structures, comprehensions, OOP)
# 3. ML workflow understanding (data prep, model selection, evaluation)
# 4. Code readability and communication
#
# ---
#
# ## Structure
# - **Part 1:** Python Fundamentals (~8 minutes)
# - **Part 2:** ML Pipeline Implementation (~12 minutes)
# - **Part 3:** Analysis & Discussion (~5 minutes)
#
# Run the setup cell below, then proceed to Part 1.

# %%
# ============================================
# SETUP - Run this cell first (no modifications needed)
# ============================================

# Standard library imports
from pathlib import Path
import sys

# Data manipulation
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt

# Scikit-learn imports (you may use these)
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Classifiers (use any of these for Part 2)
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

print("Setup complete! All libraries loaded successfully.")
print(f"NumPy version: {np.__version__}")
print(f"Pandas version: {pd.__version__}")

# %% [markdown]
# ---
#
# # Part 1: Python Fundamentals (~8 minutes)
#
# These exercises test core Python skills used daily in ML engineering.

# %% [markdown]
# ## Question 1.1: List Comprehension with Filtering
#
# Given a list of model accuracy scores, write a **single list comprehension** that:
# 1. Filters to only scores >= 0.75 (75% accuracy threshold)
# 2. Converts each passing score to a percentage string (e.g., 0.85 → "85%")
#
# **Example:** `[0.92, 0.68, 0.75, 0.89]` → `["92%", "75%", "89%"]`
#
# **Hint:** You can combine filtering (`if`) and transformation in one comprehension.

# %%
# Given data
accuracy_scores = [0.92, 0.68, 0.75, 0.81, 0.59, 0.88, 0.73, 0.95]

# TODO: Write your list comprehension here
passing_scores = None  # Replace with your solution

# Expected output: ['92%', '75%', '81%', '88%', '95%']
print(f"Passing scores: {passing_scores}")

# %% [markdown]
# ## Question 1.2: Dictionary Aggregation
#
# You have experiment results from multiple model runs. Write code to compute the **average accuracy per model type**.
#
# **Input:** List of dictionaries with model results
# **Output:** Dictionary mapping model name → average accuracy
#
# You can use any approach (loops, comprehensions, pandas, etc.) - choose what feels natural.

# %%
# Given data: Multiple runs of different models
experiment_results = [
    {"model": "RandomForest", "accuracy": 0.89},
    {"model": "LogisticRegression", "accuracy": 0.82},
    {"model": "RandomForest", "accuracy": 0.91},
    {"model": "SVM", "accuracy": 0.87},
    {"model": "LogisticRegression", "accuracy": 0.84},
    {"model": "RandomForest", "accuracy": 0.88},
    {"model": "SVM", "accuracy": 0.85},
]

# TODO: Compute average accuracy per model
avg_by_model = {}  # Your solution here

# Expected output (approximately):
# {'RandomForest': 0.893, 'LogisticRegression': 0.83, 'SVM': 0.86}
print(f"Average accuracy by model: {avg_by_model}")

# %% [markdown]
# ## Question 1.3: Simple Class with Validation
#
# Create a `ModelResult` class that stores a model's name and accuracy score.
#
# **Requirements:**
# 1. Constructor takes `name` (string) and `accuracy` (float)
# 2. Accuracy must be between 0.0 and 1.0 - raise `ValueError` if not
# 3. Add a method `is_acceptable(threshold=0.8)` that returns True if accuracy >= threshold
# 4. Add a `__str__` method that returns a formatted string like: `"RandomForest: 89.0%"`
#
# **Note:** Focus on getting the core functionality working. Error messages and edge cases are nice-to-have.

# %%
# TODO: Implement the ModelResult class
class ModelResult:
    pass  # Replace with your implementation


# Test your implementation (uncomment when ready)
# result = ModelResult("RandomForest", 0.89)
# print(result)  # Should print: RandomForest: 89.0%
# print(result.is_acceptable())  # Should print: True
# print(result.is_acceptable(threshold=0.9))  # Should print: False

# # This should raise ValueError:
# # bad_result = ModelResult("BadModel", 1.5)

# %% [markdown]
# ---
#
# # Part 2: ML Pipeline Implementation (~12 minutes)
#
# In this section, you'll build a simple classification pipeline using the Iris dataset.
#
# **Goal:** Train and evaluate a classifier, then compare at least 2 different models.
#
# The Iris dataset is a classic ML dataset:
# - 150 samples of iris flowers
# - 4 features: sepal length, sepal width, petal length, petal width
# - 3 classes: setosa, versicolor, virginica

# %% [markdown]
# ## Question 2.1: Data Preparation
#
# Load the Iris dataset and prepare it for training:
#
# 1. Load the dataset using `load_iris()`
# 2. Create feature matrix `X` and target vector `y`
# 3. Split into training (80%) and test (20%) sets with `random_state=42`
# 4. (Optional) Apply feature scaling if you think it's beneficial
#
# **Explain your reasoning:** After your code, add a brief comment explaining why you did or didn't scale the features.

# %%
# TODO: Load and prepare the data

# 1. Load the iris dataset

# 2. Create X (features) and y (target)

# 3. Split into train/test sets

# 4. (Optional) Scale features

# Print shapes to verify
# print(f"Training set: {X_train.shape[0]} samples")
# print(f"Test set: {X_test.shape[0]} samples")

# YOUR REASONING (1-2 sentences):
# Why did you choose to scale or not scale the features?

# %% [markdown]
# ## Question 2.2: Model Training and Evaluation
#
# Train **at least 2 different classifiers** and compare their performance.
#
# **Requirements:**
# 1. Train each model on the training data
# 2. Make predictions on the test data
# 3. Calculate accuracy for each model
# 4. Print a comparison of the results
#
# **Available classifiers:** LogisticRegression, DecisionTreeClassifier, RandomForestClassifier, KNeighborsClassifier, SVC
#
# **Bonus:** Use a loop or function to avoid repetitive code.

# %%
# TODO: Train and evaluate at least 2 classifiers

# Example structure (modify as needed):
# model1 = SomeClassifier()
# model1.fit(X_train, y_train)
# predictions1 = model1.predict(X_test)
# accuracy1 = accuracy_score(y_test, predictions1)

# Print comparison of results

# %% [markdown]
# ## Question 2.3: Best Model Analysis
#
# For your **best performing model**, generate:
# 1. A confusion matrix
# 2. A classification report showing precision, recall, and F1-score
#
# **Then answer:** Looking at the confusion matrix and classification report, which class (if any) is hardest for the model to classify correctly? Why might that be?

# %%
# TODO: Generate confusion matrix and classification report for best model

# Confusion Matrix

# Classification Report

# YOUR ANALYSIS (2-3 sentences):
# Which class is hardest to classify? Why might that be?

# %% [markdown]
# ---
#
# # Part 3: Discussion Questions (~5 minutes)
#
# Answer these questions in the markdown cells below. Brief answers (2-4 sentences) are fine.

# %% [markdown]
# ## Question 3.1: Model Selection
#
# If you had more time, what other approaches would you try to potentially improve model performance? Consider both different algorithms and techniques.

# %% [markdown]
# **Your Answer:**
#
# (Write your response here)

# %% [markdown]
# ## Question 3.2: Production Considerations
#
# If this model were going to production, what additional steps or considerations would be important beyond what we've done here?

# %% [markdown]
# **Your Answer:**
#
# (Write your response here)

# %% [markdown]
# ## Question 3.3: Debugging Scenario
#
# You train a model that gets 99% accuracy on the training set but only 60% on the test set. What is likely happening, and how would you address it?

# %% [markdown]
# **Your Answer:**
#
# (Write your response here)

# %% [markdown]
# ---
#
# # Interview Complete!
#
# Thank you for completing this assessment. Please let the interviewer know when you're finished.
#
# **Reminder:** Partial solutions with good reasoning are valued. If you ran out of time on any section, feel free to describe what you would have done.
