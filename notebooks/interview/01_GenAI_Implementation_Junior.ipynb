# %% [markdown]
# # 01 GenAI Implementation (Junior)
#
# ## Objective
# Build a minimal, reproducible generation pipeline with token accounting.
#
# ## Run order
# 1. Setup imports and repo path.
# 2. Load config (YAML).
# 3. Download nongated Hugging Face models (generation).
# 4. Generate text with a fixed seed.
# 5. Log token usage and save outputs.
#
# ## Notes
# - This notebook downloads nongated models from Hugging Face on first run.
# - CPU-only by default (config controls device/dtype).

# %%
# stdlib pathlib (filesystem paths)
from pathlib import Path

# src/utils/pathing.py
from src.utils.pathing import ensure_repo_root_on_sys_path  # src/utils/pathing.py

ensure_repo_root_on_sys_path(Path.cwd())
# Out:
# PosixPath('/home/goble54/spark-dev-workspace/VSP-AI-ML-Training')

# %% [markdown]
# ### Question
# Summarize why reproducibility matters in ML in one sentence.

# %% [markdown]
# #### Implementation (Score 1)
# "Reproducibility means you can run it again."

# %% [markdown]
# #### Implementation (Score 2)
# "Reproducibility means you can get the same result if you run the model again later."

# %% [markdown]
# #### Implementation (Score 3)
# "Reproducibility matters because it lets teams verify results by rerunning the same data and code to get consistent outputs."

# %% [markdown]
# #### Implementation (Score 4)
# "Reproducibility matters because it ensures results can be independently verified, compared across runs, and trusted for decisions."

# %% [markdown]
# #### Implementation (Score 5)
# "Reproducibility matters because only consistent, repeatable results allow teams to debug models, validate claims, and make reliable business decisions over time."
