# %% [markdown]
# # 08. Generative AI: Working with Knowledge Graphs - Neo4j
#
# ## Algorithm Category
# **Type**: Generative AI - Knowledge Graphs
# **Complexity**: Medium
# **Use Case**: Storing and querying structured knowledge
#
# ## Learning Objectives
#
# - Understand knowledge graphs and Neo4j
# - Write Cypher queries
# - Create nodes and relationships
# - Query graph data
#
# ## Historical Context
#
# This section covers important historical context and development of the technology.
#
# ## When to Use
#
# This approach is appropriate when you need to...

# %% [markdown]
# ## Theory & Mechanics
#
# ### What are Knowledge Graphs?
#
# Knowledge graphs represent information as networks...

# %% [markdown]
# ## Installation & Setup

# %% [markdown]
# ## Implementation

# %%
# Add project root to Python path for imports
import sys
from pathlib import Path

# Get the project root (two levels up from this notebook)
project_root = Path().resolve().parent.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.llm.neo4j_utils import connect_neo4j, create_graph_nodes, create_graph_relationships, query_neo4j
print("Neo4j utilities imported")

# %% [markdown]
# ## Validation & Testing

# %%
# Validation
print("Validation")

# %% [markdown]
# ## Performance Benchmarking

# %%
# Performance
print("Performance")

# %% [markdown]
# ## Summary & Key Takeaways
#
# - Key concept 1
# - Key concept 2
# - Key concept 3
