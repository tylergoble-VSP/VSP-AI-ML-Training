# %% [markdown]
# # 09. Generative AI: Graph RAG - RAG with Knowledge Graphs
#
# ## Algorithm Category
# **Type**: Generative AI - Graph RAG
# **Complexity**: High
# **Use Case**: Combining graph queries with LLM generation
#
# ## Learning Objectives
#
# - Understand Graph RAG architecture
# - Retrieve relevant subgraphs
# - Format graph data for LLMs
# - Implement hybrid vector + graph retrieval
#
# ## Historical Context
#
# This section covers important historical context and development of the technology.
#
# ## When to Use
#
# This approach is appropriate when you need to...

# %% [markdown]
# ## Theory & Mechanics
#
# ### What is Graph RAG?
#
# Graph RAG combines knowledge graphs with RAG...

# %% [markdown]
# ## Installation & Setup

# %% [markdown]
# ## Implementation

# %%
# Add project root to Python path for imports
import sys
from pathlib import Path

# Get the project root (two levels up from this notebook)
project_root = Path().resolve().parent.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.llm.graph_rag_utils import graph_rag_retrieve, format_graph_context, multi_hop_graph_query, hybrid_rag_retrieve
print("Graph RAG utilities imported")

# %% [markdown]
# ## Validation & Testing

# %%
# Validation
print("Validation")

# %% [markdown]
# ## Performance Benchmarking

# %%
# Performance
print("Performance")

# %% [markdown]
# ## Summary & Key Takeaways
#
# - Key concept 1
# - Key concept 2
# - Key concept 3
