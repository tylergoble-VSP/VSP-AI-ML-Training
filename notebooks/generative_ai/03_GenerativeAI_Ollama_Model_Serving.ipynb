# %% [markdown]
# # 03. Generative AI: Ollama - Running and Serving Models
#
# ## Algorithm Category
# **Type**: Generative AI - Model Serving
# **Complexity**: Low
# **Use Case**: Easy local model management and serving
#
# ## Learning Objectives
#
# - Understand Ollama and its model management capabilities
# - Use Ollama Python API for chat interactions
# - Stream responses from models
# - Manage multiple models locally
#
# ## Historical Context
#
# This section covers important historical context and development of the technology.
#
# ## When to Use
#
# This approach is appropriate when you need to...

# %% [markdown]
# ## Theory & Mechanics
#
# ### What is Ollama?
#
# Ollama is a user-friendly platform for running LLMs locally...

# %% [markdown]
# ## Installation & Setup

# %% [markdown]
# ## Implementation

# %%
# Add project root to Python path for imports
import sys
from pathlib import Path

# Get the project root (two levels up from this notebook)
project_root = Path().resolve().parent.parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from src.llm.ollama_utils import setup_ollama_client, ollama_chat, stream_ollama_response, list_ollama_models

# Setup client
client = setup_ollama_client()
print("Ollama client setup complete")

# %% [markdown]
# ## Validation & Testing

# %%
# Validation
print("Validation checks")

# %% [markdown]
# ## Performance Benchmarking

# %%
# Performance
print("Performance benchmarks")

# %% [markdown]
# ## Summary & Key Takeaways
#
# - Key concept 1
# - Key concept 2
# - Key concept 3
